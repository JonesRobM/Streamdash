# %%
pip install -r requirements.txt
# Out:
# ...
#   Obtaining dependency information for streamlit==1.29.0 from https://files.pythonhosted.org/packages/d3/96/9251b421d0a1c7d625a82a04bea56b8a9830c785940ec16db454b85c6db7/streamlit-1.29.0-py2.py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for yfinance==0.2.18 from https://files.pythonhosted.org/packages/20/e7/e8f1470e28f0532c49c37618bd141eaca5c7b99f6af23fd3794d9ef1d537/yfinance-0.2.18-py2.py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for pandas==2.1.4 from https://files.pythonhosted.org/packages/11/17/fb1a34f3e73debbc2fd15a01ea17eaab3717943d08463ff4979a4f024b3f/pandas-2.1.4-cp311-cp311-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for plotly==5.17.0 from https://files.pythonhosted.org/packages/df/79/c80174d711ee26ee5da55a9cc3e248f1ec7a0188b5e4d6bbbbcd09b974b0/plotly-5.17.0-py2.py3-none-any.whl.metadata
# ...

# %%
pip install streamlit
# Out:
# ...
#   Obtaining dependency information for streamlit from https://files.pythonhosted.org/packages/c0/4d/701f5fcf9c0d388dad9d94ba272d333c7efa6231ddee1babc59d26dc14d2/streamlit-1.47.1-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for altair<6,>=4.0 from https://files.pythonhosted.org/packages/aa/f3/0b6ced594e51cc95d8c1fc1640d3623770d01e4969d29c0bd09945fafefa/altair-5.5.0-py3-none-any.whl.metadata
#   Using cached altair-5.5.0-py3-none-any.whl.metadata (11 kB)
# ...
#   Obtaining dependency information for gitpython!=3.1.19,<4,>=3.0.7 from https://files.pythonhosted.org/packages/01/61/d4b89fec821f72385526e1b9d9a3a0385dda4a72b206d28049e2c7cd39b8/gitpython-3.1.45-py3-none-any.whl.metadata
#   Using cached gitpython-3.1.45-py3-none-any.whl.metadata (13 kB)
# ...
#   Obtaining dependency information for gitdb<5,>=4.0.1 from https://files.pythonhosted.org/packages/a0/61/5c78b91c3143ed5c14207f463aecfc8f9dbb5092fb2869baf37c273b2705/gitdb-4.0.12-py3-none-any.whl.metadata
# ...

# %%
pip install yfinance
# Out:
# ...
#   Obtaining dependency information for yfinance from https://files.pythonhosted.org/packages/c9/1e/631c80e0f97aef46eb73549b9b0f60d94057294e040740f4cad0cb1f48e4/yfinance-0.2.65-py2.py3-none-any.whl.metadata
# ...
#      ---------------------------------------- 0.0/949.2 kB ? eta -:--:--
#      ---------------------------------------- 10.2/949.2 kB ? eta -:--:--
#      -- ---------------------------------- 61.4/949.2 kB 812.7 kB/s eta 0:00:02
#      ------ ------------------------------- 174.1/949.2 kB 1.5 MB/s eta 0:00:01
#      ------------- ------------------------ 337.9/949.2 kB 2.1 MB/s eta 0:00:01
#      -------------------- ----------------- 512.0/949.2 kB 2.5 MB/s eta 0:00:01
#      ----------------------------- -------- 727.0/949.2 kB 2.9 MB/s eta 0:00:01
#      ------------------------------------ - 911.4/949.2 kB 3.2 MB/s eta 0:00:01
#      -------------------------------------- 949.2/949.2 kB 3.0 MB/s eta 0:00:00
#   Installing build dependencies: started
# ...
